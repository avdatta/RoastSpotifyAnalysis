# %%
# Just setting shit up

import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

#  needed nicer printing playlist was a mess
from pprint import pprint
# Set your Spotify API credentials
client_id = "3c70b159bb9848ca890755bf3083e080"
client_secret = "578f8808a62d4b92b5d8387d61c33432"
redirect_uri = "http://localhost:5173/callback"

# Set the required scope(s)
scope = "user-library-read"

# Set up client credentials for public data access
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Set up OAuth 2.0 for user-specific data access
auth_manager = SpotifyOAuth(client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri, scope=scope)

# Create a spotipy.Spotify instance with both client credentials and OAuth 2.0 authentication
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, auth_manager=auth_manager)



# Now lets work with our playlist
playlist_ids = [
    "44EL7fYhJJtyuSxeBXRIqN",
    "0IAV3LXxGQYEzm2QrKOYf8",
    "6Qfuh1KIkbnZE2frZIEUWV",
    "7zAzsaiXTOlSbV2mtkKyiE",
    "722Dm799mPr8aju76XL3bo",
    "0ps8V4ZUTnAqKr8hiG4KQb",
    "1gdm8lbSnyCRx2MOVPg8m3",
    "4EyTzh2SV0FDakAfWQKrDa",
    "5YCYgbyA4fMsOmA01qPdcc",
    "6BNhLEIngCJ5cfRYevuAsb",
    "45azSSsKOuhEkFIZjkqjKU",
    "3f7o8wXfeXfMe0kkpvd3vj",
    "3s4mefBOKmedL4iHGxWtai",
    "5YiFI1GlYpcf3wC0gICw45",
    "7xn5n0uTH9BAtiJ0ZWBnaT",
    "46nRxJ8j87cm9bAMsw8pY0",
    "5dlynepMBT9iQtW0N2DwmR",
    "5XgT6zWdzQYkllzRUwfXc1",
    "08L4I4xteizMqnjdul26CB",
    "7p5p5TkAqn5hrxNhG30Cuu",
    "0uDWxhEnsLuwTdRBWZH010",
    "5AxsOUXvBvOhnav4L0ILqU",
    "3iITrqFd4w2TcytrDXXt9s",
    "5PkH4QKLmxa0JwuS8hvdp8",
    "1AnHVrFyDBDhXMtyFMWQMv",
    "4Rtj9LWg01oxYGuAizckxB"
]
playlists = []

# Got it baby whohhh
for playlist_id in playlist_ids:
    playlist = sp.playlist(playlist_id)
    playlists.append(playlist)

# Now you have a list of playlists
# print(playlists)
# just way to much shit

# print(f"Playlist name: {playlist['name']}")
# print(f"Total tracks: {playlist['tracks']['total']}")

# %% [markdown]
# Ok so now that we have our playlist lets see what we can do 😈

# %%
# the lenght is 26
print(len(playlists)) 
# List of dicts
# print(playlist) way too mcuhhh
# playlist is the first playlist ever


# tracks = playlist['tracks']['items'][0]

items = playlist['tracks']['items']

# ok now i got the items aka a list of dictionaries with a bunch of assosciated info for each song
Roast_ID ={'maxhasnolife':'maxhasnolife','keshu.bk':'keshu.bk','1246008189':'Nik Nik', '128513931':'viv360','1276387946': 'brown jesus', '22aoq6nxmlhvxbyj72q2q5slq':'David From CMU' }

for item in items:
    track_name = item['track']['name']
    artist_name = item['track']['artists'][0]['name']
    contributor = item['added_by']['id']
    print(track_name, "-", artist_name, "added by", Roast_ID[contributor])
# YES 28 TRACKS

# ok cool now what can I get from this daya

#What the fuck is going on why is it only 7 tracks?
# I dont know what the length is referring to but I checked and everythign is downloaded

# Now we can mess around with it xd
# tracks = playlist['tracks']

# print(len(tracks))
# ok so this is a dictionary of tracks and each track has the following information (shit i care about)
# added at, added by(fuck I fucked this up by importing everything to the fucking gdi), track information (artists name/type?, and I guess track id), 

# A more accurate representation would be adding all the playlists by their id and importing that
#  Ok I can work on that right now I guess bluhhh

# Ok we got our playlist ids now what
# Out:
# 26
# Sunset Park - Flamingosis added by maxhasnolife
# Ole Ass Kendrick - Smino added by maxhasnolife
# Pudgy (with Lil Uzi Vert) - Smino added by maxhasnolife
# Breathe Deeper - Lil Yachty Remix - Tame Impala added by maxhasnolife
# Paris - The 1975 added by maxhasnolife
# trademark usa - Baby Keem added by keshu.bk
# family ties (with Kendrick Lamar) - Baby Keem added by keshu.bk
# south africa - Baby Keem added by keshu.bk
# VIRGO'S GROOVE - Beyoncé added by keshu.bk
# CHURCH GIRL - Beyoncé added by keshu.bk
# Steal My Attention - TOKiMONSTA added by Nik Nik
# Billie (loving arms) - Fred again.. added by Nik Nik
# Just In Time (feat. Lil Wayne & Kenny Mason) - JID added by viv360
# Bruddanem (feat. Lil Durk) - JID added by viv360
# Close To You - Dayglow added by viv360
# On Top of the World - Stephen Day added by viv360
# Taste - Rhye added by brown jesus
# I’ll Be Right There - Keen Collard added by brown jesus
# I'm Not In Love - 10cc added by brown jesus
# I Am in Love - Jennifer Lara added by brown jesus
# Don't Delete The Kisses - Tourist Remix - Wolf Alice added by brown jesus
# I'm On Fire - Bruce Springsteen added by brown jesus
# ひこうき雲 - Yumi Arai added by David From CMU
# Gettin' It (feat. Parliament Funkadelic) - Too $hort added by David From CMU
# Biggie/Tupac Live Freestyle (Funkmaster Flex & Big Kap Feat. DJ Mister Cee, Notorious B.I.G & Tupac) - Funk Flex added by David From CMU
# Are You Lonesome Tonight? - Elvis Presley added by David From CMU
# Ode Ireti - Nitefreak Remix - &friends added by Nik Nik
# Social Jungle - Hippie Sabotage Remix - Herizen added by Nik Nik

# %%
pprint(playlist)
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/4Rtj9LWg01oxYGuAizckxB'},
#  'followers': {'href': None, 'total': 7},
#  'href': 'https://api.spotify.com/v1/playlists/4Rtj9LWg01oxYGuAizckxB?additional_types=track',
#  'id': '4Rtj9LWg01oxYGuAizckxB',
#  'images': [{'height': None,
#              'url': 'https://i.scdn.co/image/ab67706c0000bebb3a361472a626fae19c13790d',
#              'width': None}],
#  'name': '10/31 to 11/6',
#  'owner': {'display_name': 'maxwu',
#            'external_urls': {'spotify': 'https://open.spotify.com/user/maxhasnolife'},
#            'href': 'https://api.spotify.com/v1/users/maxhasnolife',
#            'id': 'maxhasnolife',
#            'type': 'user',
#            'uri': 'spotify:user:maxhasnolife'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MzEsN2RmZGYwM2NiYjBkMThlNTA4MDU1MmY3MWExMGVjMTRjZmFkNThlMQ==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/4Rtj9LWg01oxYGuAizckxB/tracks?offset=0&limit=100&additional_types=track',
#             'items': [{'added_at': '2022-11-03T10:16:21Z',
#                        'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maxhasnolife'},
#                                     'href': 'https://api.spotify.com/v1/users/maxhasnolife',
#                                     'id': 'maxhasnolife',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:maxhasnolife'},
#                        'is_local': False,
#                        'primary_color': None,
#                        'track': {'album': {'album_group': 'album',
#                                            'album_type': 'album',
#                                            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75cW8FFekyCjj0mfZM1Gfb'},
#                                                         'href': 'https://api.spotify.com/v1/artists/75cW8FFekyCjj0mfZM1Gfb',
#                                                         'id': '75cW8FFekyCjj0mfZM1Gfb',
#                                                         'name': 'Flamingosis',
#                                                         'type': 'artist',
#                                                         'uri': 'spotify:artist:75cW8FFekyCjj0mfZM1Gfb'}],
#                                            'available_markets': [],
#                                            'external_urls': {'spotify': 'https://open.spotify.com/album/79A60jmAsN0A0vmbqosE6w'},
#                                            'href': 'https://api.spotify.com/v1/albums/79A60jmAsN0A0vmbqosE6w',
#                                            'id': '79A60jmAsN0A0vmbqosE6w',
#                                            'images': [{'height': 640,
#                                                        'url': 'https://i.scdn.co/image/ab67616d0000b27382cc5fddb8df9f3c89a85cfd',
#                                                        'width': 640},
#                                                       {'height': 300,
#                                                        'url': 'https://i.scdn.co/image/ab67616d00001e0282cc5fddb8df9f3c89a85cfd',
#                                                        'width': 300},
#                                                       {'height': 64,
#                                                        'url': 'https://i.scdn.co/image/ab67616d0000485182cc5fddb8df9f3c89a85cfd',
#                                                        'width': 64}],
#                                            'name': 'Bright Moments',
#                                            'release_date': '2016-08-05',
#                                            'release_date_precision': 'day',
#                                            'total_tracks': 15,
#                                            'type': 'album',
#                                            'uri': 'spotify:album:79A60jmAsN0A0vmbqosE6w'},
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75cW8FFekyCjj0mfZM1Gfb'},
#                                               'href': 'https://api.spotify.com/v1/artists/75cW8FFekyCjj0mfZM1Gfb',
#                                               'id': '75cW8FFekyCjj0mfZM1Gfb',
#                                               'name': 'Flamingosis',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:75cW8FFekyCjj0mfZM1Gfb'}],
#                                  'available_markets': [],
#                                  'disc_number': 1,
#                                  'duration_ms': 220333,
#                                  'episode': False,
#                                  'explicit': False,
#                                  'external_ids': {'isrc': 'DEQ121641327'},
#                                  'external_urls': {'spotify': 'https://open.spotify.com/track/7kPLrLCWRoevQlUY80I0nC'},
#                                  'href': 'https://api.spotify.com/v1/tracks/7kPLrLCWRoevQlUY80I0nC',
#                                  'id': '7kPLrLCWRoevQlUY80I0nC',
#                                  'is_local': False,
#                                  'name': 'Sunset Park',
#                                  'popularity': 3,
#                                  'preview_url': None,
#                                  'track': True,
#                                  'track_number': 13,
#                                  'type': 'track',
#                                  'uri': 'spotify:track:7kPLrLCWRoevQlUY80I0nC'},
#                        'video_thumbnail': {'url': None}},
#                       {'added_at': '2022-11-03T10:41:11Z',
#                        'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maxhasnolife'},
#                                     'href': 'https://api.spotify.com/v1/users/maxhasnolife',
#                                     'id': 'maxhasnolife',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:maxhasnolife'},
#                        'is_local': False,
#                        'primary_color': None,
#                        'track': {'album': {'album_group': 'album',
#                                            'album_type': 'album',
#                                            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ybINI1qPiFbwDXamRtwxD'},
#                                                         'href': 'https://api.spotify.com/v1/artists/1ybINI1qPiFbwDXamRtwxD',
#                                                         'id': '1ybINI1qPiFbwDXamRtwxD',
#                                                         'name': 'Smino',
#                                                         'type': 'artist',
#                                                         'uri': 'spotify:artist:1ybINI1qPiFbwDXamRtwxD'}],
#                                            'available_markets': ['AD',
#                                                                  'AE',
#                                                                  'AG',
#                                                                  'AL',
#                                                                  'AM',
#                                                                  'AO',
#                                                                  'AR',
#                                                                  'AT',
#                                                                  'AU',
#                                                                  'AZ',
#                                                                  'BA',
#                                                                  'BB',
#                                                                  'BD',
#                                                                  'BE',
#                                                                  'BF',
#                                                                  'BG',
#                                                                  'BH',
#                                                                  'BI',
#                                                                  'BJ',
#                                                                  'BN',
#                                                                  'BO',
#                                                                  'BR',
#                                                                  'BS',
#                                                                  'BT',
#                                                                  'BW',
#                                                                  'BZ',
#                                                                  'CA',
#                                                                  'CD',
#                                                                  'CG',
#                                                                  'CH',
#                                                                  'CI',
#                                                                  'CL',
#                                                                  'CM',
#                                                                  'CO',
#                                                                  'CR',
#                                                                  'CV',
#                                                                  'CW',
#                                                                  'CY',
#                                                                  'CZ',
#                                                                  'DE',
#                                                                  'DJ',
#                                                                  'DK',
#                                                                  'DM',
#                                                                  'DO',
#                                                                  'DZ',
#                                                                  'EC',
#                                                                  'EE',
#                                                                  'EG',
#                                                                  'ES',
#                                                                  'FI',
#                                                                  'FJ',
#                                                                  'FM',
#                                                                  'FR',
#                                                                  'GA',
#                                                                  'GB',
#                                                                  'GD',
#                                                                  'GE',
#                                                                  'GH',
#                                                                  'GM',
#                                                                  'GN',
#                                                                  'GQ',
#                                                                  'GR',
#                                                                  'GT',
#                                                                  'GW',
#                                                                  'GY',
#                                                                  'HK',
#                                                                  'HN',
#                                                                  'HR',
#                                                                  'HT',
#                                                                  'HU',
#                                                                  'ID',
#                                                                  'IE',
#                                                                  'IL',
#                                                                  'IN',
#                                                                  'IQ',
#                                                                  'IS',
#                                                                  'IT',
#                                                                  'JM',
#                                                                  'JO',
#                                                                  'JP',
#                                                                  'KE',
#                                                                  'KG',
#                                                                  'KH',
#                                                                  'KI',
#                                                                  'KM',
#                                                                  'KN',
#                                                                  'KR',
#                                                                  'KW',
#                                                                  'KZ',
#                                                                  'LA',
#                                                                  'LB',
#                                                                  'LC',
#                                                                  'LI',
#                                                                  'LK',
#                                                                  'LR',
#                                                                  'LS',
#                                                                  'LT',
#                                                                  'LU',
#                                                                  'LV',
#                                                                  'LY',
#                                                                  'MA',
#                                                                  'MC',
#                                                                  'MD',
#                                                                  'ME',
#                                                                  'MG',
#                                                                  'MH',
#                                                                  'MK',
#                                                                  'ML',
#                                                                  'MN',
#                                                                  'MO',
#                                                                  'MR',
#                                                                  'MT',
#                                                                  'MU',
#                                                                  'MV',
#                                                                  'MW',
#                                                                  'MX',
#                                                                  'MY',
#                                                                  'MZ',
#                                                                  'NA',
#                                                                  'NE',
#                                                                  'NG',
#                                                                  'NI',
#                                                                  'NL',
#                                                                  'NO',
#                                                                  'NP',
#                                                                  'NR',
#                                                                  'NZ',
#                                                                  'OM',
#                                                                  'PA',
#                                                                  'PE',
#                                                                  'PG',
#                                                                  'PH',
#                                                                  'PK',
#                                                                  'PL',
#                                                                  'PS',
#                                                                  'PT',
#                                                                  'PW',
#                                                                  'PY',
#                                                                  'QA',
#                                                                  'RO',
#                                                                  'RS',
#                                                                  'RW',
#                                                                  'SA',
#                                                                  'SB',
#                                                                  'SC',
#                                                                  'SE',
#                                                                  'SG',
#                                                                  'SI',
#                                                                  'SK',
#                                                                  'SL',
#                                                                  'SM',
#                                                                  'SN',
#                                                                  'SR',
#                                                                  'ST',
#                                                                  'SV',
#                                                                  'SZ',
#                                                                  'TD',
#                                                                  'TG',
#                                                                  'TH',
#                                                                  'TJ',
#                                                                  'TL',
#                                                                  'TN',
#                                                                  'TO',
#                                                                  'TR',
#                                                                  'TT',
#                                                                  'TV',
#                                                                  'TW',
#                                                                  'TZ',
#                                                                  'UA',
#                                                                  'UG',
#                                                                  'US',
#                                                                  'UY',
#                                                                  'UZ',
#                                                                  'VC',
#                                                                  'VE',
#                                                                  'VN',
#                                                                  'VU',
#                                                                  'WS',
#                                                                  'XK',
#                                                                  'ZA',
#                                                                  'ZM',
#                                                                  'ZW'],
#                                            'external_urls': {'spotify': 'https://open.spotify.com/album/6dtDTbVBQ9QwsNaqEnjsOT'},
#                                            'href': 'https://api.spotify.com/v1/albums/6dtDTbVBQ9QwsNaqEnjsOT',
#                                            'id': '6dtDTbVBQ9QwsNaqEnjsOT',
#                                            'images': [{'height': 640,
#                                                        'url': 'https://i.scdn.co/image/ab67616d0000b273d7bae4ad0b91f65e0dd910c8',
#                                                        'width': 640},
#                                                       {'height': 300,
#                                                        'url': 'https://i.scdn.co/image/ab67616d00001e02d7bae4ad0b91f65e0dd910c8',
#                                                        'width': 300},
#                                                       {'height': 64,
#                                                        'url': 'https://i.scdn.co/image/ab67616d00004851d7bae4ad0b91f65e0dd910c8',
#                                                        'width': 64}],
#                                            'name': 'Luv 4 Rent',
#                                            'release_date': '2022-10-28',
#                                            'release_date_precision': 'day',
#                                            'total_tracks': 15,
#                                            'type': 'album',
#                                            'uri': 'spotify:album:6dtDTbVBQ9QwsNaqEnjsOT'},
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ybINI1qPiFbwDXamRtwxD'},
#                                               'href': 'https://api.spotify.com/v1/artists/1ybINI1qPiFbwDXamRtwxD',
#                                               'id': '1ybINI1qPiFbwDXamRtwxD',
#                                               'name': 'Smino',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1ybINI1qPiFbwDXamRtwxD'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'disc_number': 1,
#                                  'duration_ms': 143640,
#                                  'episode': False,
#                                  'explicit': True,
#                                  'external_ids': {'isrc': 'USUG12207597'},
#                                  'external_urls': {'spotify': 'https://open.spotify.com/track/2qApuf4yp1c6sTMj9BJ8bo'},
#                                  'href': 'https://api.spotify.com/v1/tracks/2qApuf4yp1c6sTMj9BJ8bo',
#                                  'id': '2qApuf4yp1c6sTMj9BJ8bo',
#                                  'is_local': False,
#                                  'name': 'Ole Ass Kendrick',
#                                  'popularity': 56,
#                                  'preview_url': 'https://p.scdn.co/mp3-preview/d6cd3bcf604e918de1350fb5020a8ec81e3182cb?cid=3c70b159bb9848ca890755bf3083e080',
#                                  'track': True,
#                                  'track_number': 5,
#                                  'type': 'track',
#                                  'uri': 'spotify:track:2qApuf4yp1c6sTMj9BJ8bo'},
#                        'video_thumbnail': {'url': None}},
#                       {'added_at': '2022-11-03T11:08:04Z',
#                        'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maxhasnolife'},
#                                     'href': 'https://api.spotify.com/v1/users/maxhasnolife',
#                                     'id': 'maxhasnolife',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:maxhasnolife'},
#                        'is_local': False,
#                        'primary_color': None,
#                        'track': {'album': {'album_group': 'album',
#                                            'album_type': 'album',
#                                            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ybINI1qPiFbwDXamRtwxD'},
#                                                         'href': 'https://api.spotify.com/v1/artists/1ybINI1qPiFbwDXamRtwxD',
#                                                         'id': '1ybINI1qPiFbwDXamRtwxD',
#                                                         'name': 'Smino',
#                                                         'type': 'artist',
#                                                         'uri': 'spotify:artist:1ybINI1qPiFbwDXamRtwxD'}],
#                                            'available_markets': ['AD',
#                                                                  'AE',
#                                                                  'AG',
#                                                                  'AL',
#                                                                  'AM',
#                                                                  'AO',
#                                                                  'AR',
#                                                                  'AT',
#                                                                  'AU',
#                                                                  'AZ',
#                                                                  'BA',
#                                                                  'BB',
#                                                                  'BD',
#                                                                  'BE',
#                                                                  'BF',
#                                                                  'BG',
#                                                                  'BH',
#                                                                  'BI',
#                                                                  'BJ',
#                                                                  'BN',
#                                                                  'BO',
#                                                                  'BR',
#                                                                  'BS',
#                                                                  'BT',
#                                                                  'BW',
#                                                                  'BZ',
#                                                                  'CA',
#                                                                  'CD',
#                                                                  'CG',
#                                                                  'CH',
#                                                                  'CI',
#                                                                  'CL',
#                                                                  'CM',
#                                                                  'CO',
#                                                                  'CR',
#                                                                  'CV',
#                                                                  'CW',
#                                                                  'CY',
#                                                                  'CZ',
#                                                                  'DE',
#                                                                  'DJ',
#                                                                  'DK',
#                                                                  'DM',
#                                                                  'DO',
#                                                                  'DZ',
#                                                                  'EC',
#                                                                  'EE',
#                                                                  'EG',
#                                                                  'ES',
#                                                                  'FI',
#                                                                  'FJ',
#                                                                  'FM',
#                                                                  'FR',
#                                                                  'GA',
#                                                                  'GB',
#                                                                  'GD',
#                                                                  'GE',
#                                                                  'GH',
#                                                                  'GM',
#                                                                  'GN',
#                                                                  'GQ',
#                                                                  'GR',
#                                                                  'GT',
#                                                                  'GW',
#                                                                  'GY',
#                                                                  'HK',
#                                                                  'HN',
#                                                                  'HR',
#                                                                  'HT',
#                                                                  'HU',
#                                                                  'ID',
#                                                                  'IE',
#                                                                  'IL',
#                                                                  'IN',
#                                                                  'IQ',
#                                                                  'IS',
#                                                                  'IT',
#                                                                  'JM',
#                                                                  'JO',
#                                                                  'JP',
#                                                                  'KE',
#                                                                  'KG',
#                                                                  'KH',
#                                                                  'KI',
#                                                                  'KM',
#                                                                  'KN',
#                                                                  'KR',
#                                                                  'KW',
#                                                                  'KZ',
#                                                                  'LA',
#                                                                  'LB',
#                                                                  'LC',
#                                                                  'LI',
#                                                                  'LK',
#                                                                  'LR',
#                                                                  'LS',
#                                                                  'LT',
#                                                                  'LU',
#                                                                  'LV',
#                                                                  'LY',
#                                                                  'MA',
#                                                                  'MC',
#                                                                  'MD',
#                                                                  'ME',
#                                                                  'MG',
#                                                                  'MH',
#                                                                  'MK',
#                                                                  'ML',
#                                                                  'MN',
#                                                                  'MO',
#                                                                  'MR',
#                                                                  'MT',
#                                                                  'MU',
#                                                                  'MV',
#                                                                  'MW',
#                                                                  'MX',
#                                                                  'MY',
#                                                                  'MZ',
#                                                                  'NA',
#                                                                  'NE',
#                                                                  'NG',
#                                                                  'NI',
#                                                                  'NL',
#                                                                  'NO',
#                                                                  'NP',
#                                                                  'NR',
#                                                                  'NZ',
#                                                                  'OM',
#                                                                  'PA',
#                                                                  'PE',
#                                                                  'PG',
#                                                                  'PH',
#                                                                  'PK',
#                                                                  'PL',
#                                                                  'PS',
#                                                                  'PT',
#                                                                  'PW',
#                                                                  'PY',
#                                                                  'QA',
#                                                                  'RO',
#                                                                  'RS',
#                                                                  'RW',
#                                                                  'SA',
#                                                                  'SB',
#                                                                  'SC',
#                                                                  'SE',
#                                                                  'SG',
#                                                                  'SI',
#                                                                  'SK',
#                                                                  'SL',
#                                                                  'SM',
#                                                                  'SN',
#                                                                  'SR',
#                                                                  'ST',
#                                                                  'SV',
#                                                                  'SZ',
#                                                                  'TD',
#                                                                  'TG',
#                                                                  'TH',
#                                                                  'TJ',
#                                                                  'TL',
#                                                                  'TN',
#                                                                  'TO',
#                                                                  'TR',
#                                                                  'TT',
#                                                                  'TV',
#                                                                  'TW',
#                                                                  'TZ',
#                                                                  'UA',
#                                                                  'UG',
#                                                                  'US',
#                                                                  'UY',
#                                                                  'UZ',
#                                                                  'VC',
#                                                                  'VE',
# ...
#                                                                  'VC',
#                                                                  'VE',
#                                                                  'VN',
#                                                                  'VU',
#                                                                  'WS',
#                                                                  'XK',
#                                                                  'ZA',
#                                                                  'ZM',
#                                                                  'ZW'],
#                                            'external_urls': {'spotify': 'https://open.spotify.com/album/1ieAAhsCYApk763sKtTgCB'},
#                                            'href': 'https://api.spotify.com/v1/albums/1ieAAhsCYApk763sKtTgCB',
#                                            'id': '1ieAAhsCYApk763sKtTgCB',
#                                            'images': [{'height': 640,
#                                                        'url': 'https://i.scdn.co/image/ab67616d0000b2730ef323fbc1fbcce09e900cfb',
#                                                        'width': 640},
#                                                       {'height': 300,
#                                                        'url': 'https://i.scdn.co/image/ab67616d00001e020ef323fbc1fbcce09e900cfb',
#                                                        'width': 300},
#                                                       {'height': 64,
#                                                        'url': 'https://i.scdn.co/image/ab67616d000048510ef323fbc1fbcce09e900cfb',
#                                                        'width': 64}],
#                                            'name': 'Social Jungle (Remixes)',
#                                            'release_date': '2018-09-07',
#                                            'release_date_precision': 'day',
#                                            'total_tracks': 3,
#                                            'type': 'album',
#                                            'uri': 'spotify:album:1ieAAhsCYApk763sKtTgCB'},
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3niPESDNKjDtTNfWzxZkXv'},
#                                               'href': 'https://api.spotify.com/v1/artists/3niPESDNKjDtTNfWzxZkXv',
#                                               'id': '3niPESDNKjDtTNfWzxZkXv',
#                                               'name': 'Herizen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3niPESDNKjDtTNfWzxZkXv'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dM6NDYSfLcspt8GLoT5aE'},
#                                               'href': 'https://api.spotify.com/v1/artists/4dM6NDYSfLcspt8GLoT5aE',
#                                               'id': '4dM6NDYSfLcspt8GLoT5aE',
#                                               'name': 'Hippie Sabotage',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4dM6NDYSfLcspt8GLoT5aE'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'disc_number': 1,
#                                  'duration_ms': 280975,
#                                  'episode': False,
#                                  'explicit': False,
#                                  'external_ids': {'isrc': 'GBKPL1820762'},
#                                  'external_urls': {'spotify': 'https://open.spotify.com/track/0MiWH0qt7s1NaLywTKAB7q'},
#                                  'href': 'https://api.spotify.com/v1/tracks/0MiWH0qt7s1NaLywTKAB7q',
#                                  'id': '0MiWH0qt7s1NaLywTKAB7q',
#                                  'is_local': False,
#                                  'name': 'Social Jungle - Hippie Sabotage '
#                                          'Remix',
#                                  'popularity': 48,
#                                  'preview_url': 'https://p.scdn.co/mp3-preview/2a42f0f81b450a47c025652d6aa91791544a28c3?cid=3c70b159bb9848ca890755bf3083e080',
#                                  'track': True,
#                                  'track_number': 1,
#                                  'type': 'track',
#                                  'uri': 'spotify:track:0MiWH0qt7s1NaLywTKAB7q'},
#                        'video_thumbnail': {'url': None}}],
#             'limit': 100,
#             'next': None,
#             'offset': 0,
#             'previous': None,
#             'total': 28},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:4Rtj9LWg01oxYGuAizckxB'}
