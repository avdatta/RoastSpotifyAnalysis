# %%
# Just setting shit up

import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

#  needed nicer printing playlist was a mess
from pprint import pprint
# Set your Spotify API credentials
client_id = "3c70b159bb9848ca890755bf3083e080"
client_secret = "578f8808a62d4b92b5d8387d61c33432"
redirect_uri = "http://localhost:5173/callback"

# Set the required scope(s)
scope = "user-library-read"

# Set up client credentials for public data access
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Set up OAuth 2.0 for user-specific data access
auth_manager = SpotifyOAuth(client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri, scope=scope)

# Create a spotipy.Spotify instance with both client credentials and OAuth 2.0 authentication
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, auth_manager=auth_manager)



# Now lets work with our playlist
playlist_ids = [
    "44EL7fYhJJtyuSxeBXRIqN",
    "0IAV3LXxGQYEzm2QrKOYf8",
    "6Qfuh1KIkbnZE2frZIEUWV",
    "7zAzsaiXTOlSbV2mtkKyiE",
    "722Dm799mPr8aju76XL3bo",
    "0ps8V4ZUTnAqKr8hiG4KQb",
    "1gdm8lbSnyCRx2MOVPg8m3",
    "4EyTzh2SV0FDakAfWQKrDa",
    "5YCYgbyA4fMsOmA01qPdcc",
    "6BNhLEIngCJ5cfRYevuAsb",
    "45azSSsKOuhEkFIZjkqjKU",
    "3f7o8wXfeXfMe0kkpvd3vj",
    "3s4mefBOKmedL4iHGxWtai",
    "5YiFI1GlYpcf3wC0gICw45",
    "7xn5n0uTH9BAtiJ0ZWBnaT",
    "46nRxJ8j87cm9bAMsw8pY0",
    "5dlynepMBT9iQtW0N2DwmR",
    "5XgT6zWdzQYkllzRUwfXc1",
    "08L4I4xteizMqnjdul26CB",
    "7p5p5TkAqn5hrxNhG30Cuu",
    "0uDWxhEnsLuwTdRBWZH010",
    "5AxsOUXvBvOhnav4L0ILqU",
    "3iITrqFd4w2TcytrDXXt9s",
    "5PkH4QKLmxa0JwuS8hvdp8",
    "1AnHVrFyDBDhXMtyFMWQMv",
    "4Rtj9LWg01oxYGuAizckxB"
]
playlists = []

# Got it baby whohhh
for playlist_id in playlist_ids:
    playlist = sp.playlist(playlist_id)
    playlists.append(playlist)

# Now you have a list of playlists
# print(playlists)
# just way to much shit

# print(f"Playlist name: {playlist['name']}")
# print(f"Total tracks: {playlist['tracks']['total']}")

# %%
from collections import Counter

# %% [markdown]
# Ok so now that we have our playlist lets see what we can do 😈

# %%
# the lenght is 26
print(len(playlists)) 
# List of dicts
# print(playlist) way too mcuhhh
# playlist is the first playlist ever


# tracks = playlist['tracks']['items'][0]

items = playlist['tracks']['items']

# ok now i got the items aka a list of dictionaries with a bunch of assosciated info for each song
Roast_ID ={'maxhasnolife':'maxhasnolife','keshu.bk':'keshu.bk','1246008189':'Nik Nik', '128513931':'viv360','1276387946': 'brown jesus', '22aoq6nxmlhvxbyj72q2q5slq':'David From CMU' }


artist_count = {}
for item in items:
    track_name = item['track']['name']
    artist_name = item['track']['artists'][0]['name']
    contributor = item['added_by']['id']
    print(track_name, "-", artist_name, "added by", Roast_ID[contributor])
    if artist_name in artist_count:
        artist_count[artist_name]+=1
    else:
        artist_count[artist_name] = 1
    
sorted_artists = sorted(artist_count.items(), key=lambda x: x[1], reverse=True)

for artist,count in sorted_artists:
    print(f"{artist} shows up {count} times")

print(len(sorted_artists))

# Its possible I didn't add the features or if collab. I only did one sue me

# YES 28 TRACKS

# ok cool now what can I get from this daya

#What the fuck is going on why is it only 7 tracks?
# I dont know what the length is referring to but I checked and everythign is downloaded

# Now we can mess around with it xd
# tracks = playlist['tracks']

# print(len(tracks))
# ok so this is a dictionary of tracks and each track has the following information (shit i care about)
# added at, added by(fuck I fucked this up by importing everything to the fucking gdi), track information (artists name/type?, and I guess track id), 

# A more accurate representation would be adding all the playlists by their id and importing that
#  Ok I can work on that right now I guess bluhhh

# Ok we got our playlist ids now what
# Out:
# 26
# Sunset Park - Flamingosis added by maxhasnolife
# Ole Ass Kendrick - Smino added by maxhasnolife
# Pudgy (with Lil Uzi Vert) - Smino added by maxhasnolife
# Breathe Deeper - Lil Yachty Remix - Tame Impala added by maxhasnolife
# Paris - The 1975 added by maxhasnolife
# trademark usa - Baby Keem added by keshu.bk
# family ties (with Kendrick Lamar) - Baby Keem added by keshu.bk
# south africa - Baby Keem added by keshu.bk
# VIRGO'S GROOVE - Beyoncé added by keshu.bk
# CHURCH GIRL - Beyoncé added by keshu.bk
# Steal My Attention - TOKiMONSTA added by Nik Nik
# Billie (loving arms) - Fred again.. added by Nik Nik
# Just In Time (feat. Lil Wayne & Kenny Mason) - JID added by viv360
# Bruddanem (feat. Lil Durk) - JID added by viv360
# Close To You - Dayglow added by viv360
# On Top of the World - Stephen Day added by viv360
# Taste - Rhye added by brown jesus
# I’ll Be Right There - Keen Collard added by brown jesus
# I'm Not In Love - 10cc added by brown jesus
# I Am in Love - Jennifer Lara added by brown jesus
# Don't Delete The Kisses - Tourist Remix - Wolf Alice added by brown jesus
# I'm On Fire - Bruce Springsteen added by brown jesus
# ひこうき雲 - Yumi Arai added by David From CMU
# Gettin' It (feat. Parliament Funkadelic) - Too $hort added by David From CMU
# Biggie/Tupac Live Freestyle (Funkmaster Flex & Big Kap Feat. DJ Mister Cee, Notorious B.I.G & Tupac) - Funk Flex added by David From CMU
# Are You Lonesome Tonight? - Elvis Presley added by David From CMU
# Ode Ireti - Nitefreak Remix - &friends added by Nik Nik
# Social Jungle - Hippie Sabotage Remix - Herizen added by Nik Nik
# Baby Keem shows up 3 times
# Smino shows up 2 times
# Beyoncé shows up 2 times
# JID shows up 2 times
# Flamingosis shows up 1 times
# Tame Impala shows up 1 times
# The 1975 shows up 1 times
# TOKiMONSTA shows up 1 times
# Fred again.. shows up 1 times
# Dayglow shows up 1 times
# Stephen Day shows up 1 times
# Rhye shows up 1 times
# Keen Collard shows up 1 times
# 10cc shows up 1 times
# Jennifer Lara shows up 1 times
# Wolf Alice shows up 1 times
# Bruce Springsteen shows up 1 times
# Yumi Arai shows up 1 times
# Too $hort shows up 1 times
# Funk Flex shows up 1 times
# Elvis Presley shows up 1 times
# &friends shows up 1 times
# Herizen shows up 1 times
# 23

# %%
# how to get to the track id
# pprint(items[0]['track'])
# track analysis ok kinda did this
# artist -> genre let me try this out
#album analysis
# popularity of song
# 
sp.audio_analysis('7kPLrLCWRoevQlUY80I0nC')
pprint(sp.audio_features('7kPLrLCWRoevQlUY80I0nC'))
# track': {'num_samples': 4858350,
#   'duration': 220.33333,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.0,
#   'start_of_fade_out': 201.10803,
#   'loudness': -10.181,
#   'tempo': 90.004,
#   'tempo_confidence': 0.187,
#   'time_signature': 4,
#   'time_signature_confidence': 0.984,
#   'key': 6,
#   'key_confidence': 0.913,
#   'mode': 0,
#   'mode_confidence': 0.727,

# wtf are codestring,synchstring.rhythmstring, What kinds of information can you encode with letters like that i guess base52 system
# interesting question

print('\n\n\n\n\n')
# Artist analysis (What can i do with the id number)
sp.artist('75cW8FFekyCjj0mfZM1Gfb')
# number of followers, genres, images?, popularity
# i can get related artists for every track someone reccomends and accumulate an artist 
# recommendation list for everyone based of who they've put
# Out:
# [{'acousticness': 0.00368,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kPLrLCWRoevQlUY80I0nC',
#   'danceability': 0.562,
#   'duration_ms': 220333,
#   'energy': 0.698,
#   'id': '7kPLrLCWRoevQlUY80I0nC',
#   'instrumentalness': 0.67,
#   'key': 6,
#   'liveness': 0.365,
#   'loudness': -10.181,
#   'mode': 0,
#   'speechiness': 0.0338,
#   'tempo': 90.004,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7kPLrLCWRoevQlUY80I0nC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7kPLrLCWRoevQlUY80I0nC',
#   'valence': 0.679}]
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/75cW8FFekyCjj0mfZM1Gfb'},
#  'followers': {'href': None, 'total': 158085},
#  'genres': ['chillhop', 'future funk'],
#  'href': 'https://api.spotify.com/v1/artists/75cW8FFekyCjj0mfZM1Gfb',
#  'id': '75cW8FFekyCjj0mfZM1Gfb',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb67f3f9d43078b84a969c5fba',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517467f3f9d43078b84a969c5fba',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17867f3f9d43078b84a969c5fba',
#    'width': 160}],
#  'name': 'Flamingosis',
#  'popularity': 51,
#  'type': 'artist',
#  'uri': 'spotify:artist:75cW8FFekyCjj0mfZM1Gfb'}

# %% [markdown]
# Ok what features do I want to implement. First thing we need to do is have an artist count. I've made the playlist importing such that there are doubles so thats unfortunate but Ithink also representative of something actually. Ok I have artist count. I was also thinking some networkX stuff showing up on top of matplotlib. Today lets just get more and more characteristics. Also we're just gonna do it on one playlist it shouldn't be tough to expand to 26 playlists.
#
# i'm going to try the audio analysis function.

# %%
# LOL

#grab the artist ids
artist_info = [artist for track in playlist['tracks']['items'] for artist in track['track']['artists']]



artist_ids = [artist['id'] for artist in artist_info]


#we'll keep the duplicates magnitude matters
#or we can do both 





genre_count_doubles = Counter()
genre_count_unique = Counter()

for id in artist_ids:
    genre_count_doubles.update(sp.artist(str(id))['genres'])



for id in list(set(artist_ids)):
    genre_count_unique.update(sp.artist(str(id))['genres'])


for genre, count in sorted(genre_count_unique.items(), key=lambda x: x[1], reverse=True):
    print(f"{genre.capitalize()}: {count}")

# for genre, count in sorted(genre_count_doubles.items(), key=lambda x: x[1], reverse=True):
#     print(f"{genre.capitalize()}: {count}")

# ok i have my genres now

# %%
#audio analysis by person
#how much did everyone contribute
# The complexity of the user and how to manage their information is interesting. 
# Escalates like crazy
# Made the executive decision to keep as much information with each ite
# pprint(playlist)

sorted_tracks = {}
for playlist in playlists:
    for item in playlist['tracks']['items']:
        if item['added_by']['id'] in sorted_tracks.keys():
            sorted_tracks[item['added_by']['id']].append(item)
        else:
            sorted_tracks[item['added_by']['id']]=[item]
    
# we now have a dict in the playlist sorted by freaking person! Honestly wanna just make one rn with every song?
# DONE!!!!✨


    
# ok im thinking i have a dictionary where the key is the perosn id. and that dictionary will have the "item"
# yay done

# %%
print(len(sorted_tracks['maxhasnolife']))
# LETSFUCKINGGOOO

# ok ideally we compile a bunch of information about each collection of songs and again it would be based off the same "id"
print(sorted_tracks.keys())

# make keys MATCH! (Be careful though this will have to be something accounted for later?!)
print(Roast_ID)


# 
# for key in sorted_tracks.keys():
#     print(key)
#     if key.isdigit():
#         sorted_tracks[Roast_ID[key]] = sorted_tracks[key]
#         del sorted_tracks[key]
# sorted_tracks['Probably_Ali'] = sorted_tracks['0rgldmkhwpwevoagjfwti12s9']
# del sorted_tracks['0rgldmkhwpwevoagjfwti12s9']
# Out:
# 212
# dict_keys(['maxhasnolife', 'roro5179', 'keshu.bk', 'dalegend2', '0rgldmkhwpwevoagjfwti12s9', 'not6sarbo', 'David From CMU', 'Nik Nik', 'brown jesus', 'viv360'])
# {'maxhasnolife': 'maxhasnolife', 'keshu.bk': 'keshu.bk', '1246008189': 'Nik Nik', '128513931': 'viv360', '1276387946': 'brown jesus', '22aoq6nxmlhvxbyj72q2q5slq': 'David From CMU'}

# %%
# genre count for everyone
# sorted_tracks['maxhasnolife']
# genre_count = {}
# for key in sorted_tracks.keys():
#     for item in sorted_tracks[key]:
#             if key not in genre_count.keys():
#                 genre_count[key] = Counter()
#             # grab artist ids for item
#             artist_ids = [artist['id'] for artist in item['track']['artists']]
#             for id in artist_ids:
#                 genre_count[key].update(sp.artist(str(id))['genres'])

import requests

genre_count = {}

for key in sorted_tracks.keys():
    for item in sorted_tracks[key]:
        if key not in genre_count.keys():
            genre_count[key] = Counter()

        # Grab artist IDs for the item
        artist_ids = [artist['id'] for artist in item['track']['artists']]

        for id in artist_ids:
            try:
                # Get artist information from the Spotify API
                artist_data = sp.artist(str(id))
                genres = artist_data['genres']
                genre_count[key].update(genres)
            except requests.exceptions.HTTPError as e:
                # Handle specific HTTP error status codes as needed
                if e.response.status_code == 404:
                    print(f"Artist not found with ID {id}.")
                else:
                    print(f"An error occurred while fetching artist data: {e}")
            except Exception as e:
                # Catch any other exceptions and print a generic error message
                print(f"An unexpected error occurred: {e}")

        
# need to error handle
# 10lMwCjvzLCLwth2AW6cLG shoutout to this artist id
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/artists/10lMwCjvzLCLwth2AW6cLG with Params: {} returned 404 due to non existing id
# An unexpected error occurred: http status: 404, code:-1 - https://api.spotify.com/v1/artists/10lMwCjvzLCLwth2AW6cLG:
#  non existing id, reason: None
# HTTP Error for GET to https://api.spotify.com/v1/artists/10lMwCjvzLCLwth2AW6cLG with Params: {} returned 404 due to non existing id
# An unexpected error occurred: http status: 404, code:-1 - https://api.spotify.com/v1/artists/10lMwCjvzLCLwth2AW6cLG:
#  non existing id, reason: None

# %%
# for key in sorted_tracks.keys():
#     print(f"{key} top 5 genres!!")
#     for genre, count in sorted(genre_count[key].items(), key=lambda x: x[1], reverse=True)[:5]:
#         print(f"{genre.capitalize()}: {count}")
#     print('\n')

#Fire we have everyone genres in the genre_count dictionary.
# Any information from sp.artist(We can compile)

#Now lets get everyones audio information with the sp.

# theres an audio_features func p nice
# create a list of track ids for each person for the audio features thing
# first lets see what i can do with one track id


pprint(sp.audio_analysis('59GW6EKtdyaJ10t2yQdqrt'))
# for item in sorted_tracks['maxhasnolife']:
#     print(item['track']['id'])
# Out:
# {'bars': [{'confidence': 0.766, 'duration': 1.91469, 'start': 0.11032},
#           {'confidence': 0.863, 'duration': 1.90235, 'start': 2.02502},
#           {'confidence': 0.707, 'duration': 1.90227, 'start': 3.92737},
#           {'confidence': 0.766, 'duration': 1.90583, 'start': 5.82963},
#           {'confidence': 0.727, 'duration': 1.90761, 'start': 7.73546},
#           {'confidence': 0.602, 'duration': 1.90308, 'start': 9.64307},
#           {'confidence': 0.815, 'duration': 1.90151, 'start': 11.54615},
#           {'confidence': 0.676, 'duration': 1.90487, 'start': 13.44766},
#           {'confidence': 0.872, 'duration': 1.9098, 'start': 15.35252},
#           {'confidence': 0.137, 'duration': 1.90574, 'start': 17.26232},
#           {'confidence': 0.899, 'duration': 1.90232, 'start': 19.16806},
#           {'confidence': 0.74, 'duration': 1.9044, 'start': 21.07037},
#           {'confidence': 0.81, 'duration': 1.90855, 'start': 22.97477},
#           {'confidence': 0.5, 'duration': 1.90381, 'start': 24.88333},
#           {'confidence': 0.899, 'duration': 1.90073, 'start': 26.78714},
#           {'confidence': 0.655, 'duration': 1.90713, 'start': 28.68787},
#           {'confidence': 0.68, 'duration': 1.90825, 'start': 30.59499},
#           {'confidence': 0.332, 'duration': 1.90507, 'start': 32.50324},
#           {'confidence': 0.937, 'duration': 1.8995, 'start': 34.40831},
#           {'confidence': 0.756, 'duration': 1.90091, 'start': 36.30781},
#           {'confidence': 0.593, 'duration': 1.91028, 'start': 38.20872},
#           {'confidence': 0.648, 'duration': 1.90566, 'start': 40.119},
#           {'confidence': 0.85, 'duration': 1.90291, 'start': 42.02466},
#           {'confidence': 0.562, 'duration': 1.907, 'start': 43.92757},
#           {'confidence': 0.85, 'duration': 1.90368, 'start': 45.83458},
#           {'confidence': 0.547, 'duration': 1.90412, 'start': 47.73826},
#           {'confidence': 0.831, 'duration': 1.903, 'start': 49.64238},
#           {'confidence': 0.468, 'duration': 1.90741, 'start': 51.54538},
#           {'confidence': 0.916, 'duration': 1.90345, 'start': 53.45279},
#           {'confidence': 0.837, 'duration': 1.90615, 'start': 55.35624},
#           {'confidence': 0.793, 'duration': 1.90591, 'start': 57.26239},
#           {'confidence': 0.791, 'duration': 1.90075, 'start': 59.1683},
#           {'confidence': 0.877, 'duration': 1.9047, 'start': 61.06906},
#           {'confidence': 0.85, 'duration': 1.90398, 'start': 62.97375},
#           {'confidence': 0.607, 'duration': 1.90341, 'start': 64.87773},
#           {'confidence': 0.442, 'duration': 1.91038, 'start': 66.78115},
#           {'confidence': 0.882, 'duration': 1.90622, 'start': 68.69153},
#           {'confidence': 0.514, 'duration': 1.90266, 'start': 70.59775},
#           {'confidence': 0.862, 'duration': 1.90263, 'start': 72.50042},
#           {'confidence': 0.853, 'duration': 1.90587, 'start': 74.40305},
#           {'confidence': 0.864, 'duration': 1.90667, 'start': 76.30892},
#           {'confidence': 0.782, 'duration': 1.90155, 'start': 78.21559},
#           {'confidence': 0.839, 'duration': 1.90206, 'start': 80.11715},
#           {'confidence': 0.855, 'duration': 1.90942, 'start': 82.01921},
#           {'confidence': 0.833, 'duration': 1.90771, 'start': 83.92863},
#           {'confidence': 0.692, 'duration': 1.90004, 'start': 85.83634},
#           {'confidence': 0.699, 'duration': 1.90121, 'start': 87.73638},
#           {'confidence': 0.874, 'duration': 1.90812, 'start': 89.6376},
#           {'confidence': 0.737, 'duration': 1.90989, 'start': 91.54572},
#           {'confidence': 0.636, 'duration': 1.90614, 'start': 93.45561},
#           {'confidence': 0.857, 'duration': 1.90385, 'start': 95.36175},
#           {'confidence': 0.778, 'duration': 1.89364, 'start': 97.2656},
#           {'confidence': 0.233, 'duration': 1.88381, 'start': 99.15923},
#           {'confidence': 0.441, 'duration': 1.93839, 'start': 101.04304},
#           {'confidence': 0.576, 'duration': 1.92757, 'start': 102.98143},
#           {'confidence': 0.248, 'duration': 1.89051, 'start': 104.909},
#           {'confidence': 0.387, 'duration': 1.91076, 'start': 106.79951},
#           {'confidence': 0.391, 'duration': 1.89879, 'start': 108.71026},
#           {'confidence': 0.806, 'duration': 1.88946, 'start': 110.60905},
#           {'confidence': 0.463, 'duration': 1.90377, 'start': 112.49851},
#           {'confidence': 0.793, 'duration': 1.9145, 'start': 114.40228},
#           {'confidence': 0.597, 'duration': 1.90273, 'start': 116.31678},
#           {'confidence': 0.895, 'duration': 1.90154, 'start': 118.21951},
#           {'confidence': 0.423, 'duration': 1.90652, 'start': 120.12106},
#           {'confidence': 0.817, 'duration': 1.90711, 'start': 122.02757},
#           {'confidence': 0.615, 'duration': 1.90267, 'start': 123.93468},
#           {'confidence': 0.907, 'duration': 1.9009, 'start': 125.83735},
#           {'confidence': 0.737, 'duration': 1.90861, 'start': 127.73825},
#           {'confidence': 0.633, 'duration': 1.90827, 'start': 129.64687},
#           {'confidence': 0.293, 'duration': 1.89995, 'start': 131.55513},
#           {'confidence': 0.854, 'duration': 1.90266, 'start': 133.45508},
#           {'confidence': 0.851, 'duration': 1.90759, 'start': 135.35774},
#           {'confidence': 0.516, 'duration': 1.90726, 'start': 137.26534},
#           {'confidence': 0.21, 'duration': 1.90159, 'start': 139.17259},
#           {'confidence': 0.58, 'duration': 1.90277, 'start': 141.07417},
#           {'confidence': 0.713, 'duration': 1.91175, 'start': 142.97696},
#           {'confidence': 0.434, 'duration': 1.90771, 'start': 144.8887},
#           {'confidence': 0.623, 'duration': 1.89882, 'start': 146.79642},
#           {'confidence': 0.826, 'duration': 1.9016, 'start': 148.69524},
#            {'confidence': 0.397, 'duration': 0.4745, 'start': 146.79642},
#            {'confidence': 0.328, 'duration': 0.47477, 'start': 147.2709},
#            {'confidence': 0.421, 'duration': 0.47463, 'start': 147.74568},
#            {'confidence': 0.332, 'duration': 0.47492, 'start': 148.2203},
#            {'confidence': 0.352, 'duration': 0.47462, 'start': 148.69524},
#            {'confidence': 0.367, 'duration': 0.47455, 'start': 149.16985},
#            {'confidence': 0.447, 'duration': 0.47532, 'start': 149.64441},
#            {'confidence': 0.412, 'duration': 0.47711, 'start': 150.11972},
#            {'confidence': 0.437, 'duration': 0.47997, 'start': 150.59683},
#            {'confidence': 0.376, 'duration': 0.48094, 'start': 151.0768},
#            {'confidence': 0.4, 'duration': 0.48085, 'start': 151.55772},
#            {'confidence': 0.269, 'duration': 0.48096, 'start': 152.03857},
#            {'confidence': 0.188, 'duration': 0.48085, 'start': 152.51953},
#            {'confidence': 0.316, 'duration': 0.4799, 'start': 153.0004},
#            {'confidence': 0.326, 'duration': 0.47728, 'start': 153.48029},
#            {'confidence': 0.249, 'duration': 0.47486, 'start': 153.95758},
#            {'confidence': 0.201, 'duration': 0.47471, 'start': 154.43243},
#            {'confidence': 0.26, 'duration': 0.47475, 'start': 154.90715},
#            {'confidence': 0.303, 'duration': 0.47475, 'start': 155.3819},
#            {'confidence': 0.262, 'duration': 0.4739, 'start': 155.85664},
#            {'confidence': 0.182, 'duration': 0.47303, 'start': 156.33055},
#            {'confidence': 0.113, 'duration': 0.47363, 'start': 156.80357},
#            {'confidence': 0.164, 'duration': 0.47382, 'start': 157.2772},
#            {'confidence': 0.179, 'duration': 0.47236, 'start': 157.75102},
#            {'confidence': 0.16, 'duration': 0.47131, 'start': 158.22337},
#            {'confidence': 0.218, 'duration': 0.47635, 'start': 158.69469},
#            {'confidence': 0.15, 'duration': 0.48078, 'start': 159.17104},
#            {'confidence': 0.15, 'duration': 0.47567, 'start': 159.65182}],
#  'meta': {'analysis_time': 5.83607,
#           'analyzer_version': '4.0.0',
#           'detailed_status': 'OK',
#           'input_process': 'libvorbisfile L+R 44100->22050',
#           'platform': 'Linux',
#           'status_code': 0,
#           'timestamp': 1678300465},
#  'sections': [{'confidence': 1.0,
#                'duration': 8.21275,
#                'key': 10,
#                'key_confidence': 0.08,
#                'loudness': -7.062,
#                'mode': 0,
#                'mode_confidence': 0.41,
#                'start': 0.0,
#                'tempo': 126.044,
#                'tempo_confidence': 0.805,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.642,
#                'duration': 30.95,
#                'key': 6,
#                'key_confidence': 0.13,
#                'loudness': -5.253,
#                'mode': 1,
#                'mode_confidence': 0.51,
#                'start': 8.21275,
#                'tempo': 126.004,
#                'tempo_confidence': 0.53,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.577,
#                'duration': 30.95871,
#                'key': 10,
#                'key_confidence': 0.55,
#                'loudness': -4.615,
#                'mode': 0,
#                'mode_confidence': 0.599,
#                'start': 39.16275,
#                'tempo': 126.045,
#                'tempo_confidence': 0.61,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.462,
#                'duration': 29.50701,
#                'key': 10,
#                'key_confidence': 0.0,
#                'loudness': -4.142,
#                'mode': 0,
#                'mode_confidence': 0.0,
#                'start': 70.12146,
#                'tempo': 126.098,
#                'tempo_confidence': 0.489,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 1.0,
#                'duration': 14.77381,
#                'key': 10,
#                'key_confidence': 0.459,
#                'loudness': -12.159,
#                'mode': 0,
#                'mode_confidence': 0.646,
#                'start': 99.62847,
#                'tempo': 126.117,
#                'tempo_confidence': 0.346,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.909,
#                'duration': 15.72198,
#                'key': 10,
#                'key_confidence': 0.068,
#                'loudness': -4.829,
#                'mode': 0,
#                'mode_confidence': 0.417,
#                'start': 114.40228,
#                'tempo': 126.058,
#                'tempo_confidence': 0.512,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.25,
#                'duration': 30.00322,
#                'key': 6,
#                'key_confidence': 0.149,
#                'loudness': -3.475,
#                'mode': 1,
#                'mode_confidence': 0.549,
#                'start': 130.12427,
#                'tempo': 125.913,
#                'tempo_confidence': 0.351,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0}],
#  'segments': [{'confidence': 0.0,
#                'duration': 0.10458,
#                'loudness_end': 0.0,
#                'loudness_max': -60.0,
#                'loudness_max_time': 0.0,
#                'loudness_start': -60.0,
#                'pitches': [1.0,
#                            0.845,
#                            0.82,
#                            0.74,
#                            0.495,
#                            0.569,
#                            0.36,
#                            0.605,
#                            0.432,
#                            0.339,
#                            0.264,
#                            0.563],
#                'start': 0.0,
#                'timbre': [2.289,
#                           163.557,
#                           37.832,
#                           -89.958,
#                           56.788,
#                           -77.972,
#                           25.584,
#                           -26.681,
#                           -27.017,
#                           1.276,
#                           44.63,
#                           -15.218]},
#               {'confidence': 1.0,
#                'duration': 0.19814,
#                'loudness_end': 0.0,
#                'loudness_max': -4.464,
#                'loudness_max_time': 0.02223,
#                'loudness_start': -60.0,
#                'pitches': [0.433,
#                            0.222,
#                            0.159,
#                            0.281,
#                            0.285,
#                            0.518,
#                            0.9,
#                            0.911,
#                            0.671,
#                            1.0,
#                            0.746,
#                            0.528],
#                'start': 0.10458,
#                'timbre': [46.392,
#                           69.594,
#                           -75.974,
#                           97.076,
#                           67.036,
#                           -78.836,
#                           -21.817,
#                           9.494,
#                           -2.136,
#                           -11.752,
#                           3.1,
#                           -11.138]},
#               {'confidence': 0.843,
#                'duration': 0.13211,
#                'loudness_end': 0.0,
#                'loudness_max': -12.696,
#                'loudness_max_time': 0.05202,
#                'loudness_start': -25.476,
#                'pitches': [0.374,
#                            0.375,
#                            0.312,
#                            0.297,
#                            0.467,
#                            0.569,
#                            0.247,
#                            0.327,
#                            0.5,
#                            0.746,
#                            1.0,
#                            0.494],
#                'start': 0.30272,
#                'timbre': [39.304,
#                           61.205,
#                           9.56,
#                           -14.416,
#                           127.129,
#                           24.294,
#                           -16.774,
#                           35.549,
#                           19.629,
#                           -80.128,
#                           -42.989,
#                           9.144]},
#               {'confidence': 0.861,
#                'duration': 0.14558,
#                'loudness_end': 0.0,
#                'loudness_max': -15.287,
#                'loudness_max_time': 0.06031,
#                'loudness_start': -26.506,
#                'pitches': [0.227,
#                            0.103,
#                            0.085,
#                            0.078,
#                            0.048,
#                            0.1,
#                            0.069,
#                            1.0,
#                            0.528,
#                            0.129,
#                            0.089,
#                            0.076],
#                'start': 0.43483,
#                'timbre': [39.61,
#                           27.133,
#                           38.398,
#                           -25.673,
#                           129.187,
#                           9.162,
#                           11.652,
#                           -20.235,
#                           8.024,
#                           -11.268,
#                           -25.536,
#                           12.563]},
#               {'confidence': 1.0,
#                'duration': 0.2263,
#                'loudness_end': 0.0,
#                'loudness_max': -1.977,
#                'loudness_max_time': 0.01174,
#                'loudness_start': -23.153,
#                'pitches': [0.411,
#                            0.203,
#                            0.253,
#                            0.282,
#                            0.29,
#                            0.409,
#                            0.56,
#                            0.624,
#                            0.578,
#                            0.514,
#                            1.0,
#                            0.444],
#                'start': 0.58041,
#                'timbre': [48.554,
#                           83.054,
#                           -12.761,
#                           160.227,
#                           93.673,
#                           -62.331,
#                           -26.336,
#                           0.549,
#                           -4.102,
#                           -36.067,
#                           -43.493,
#                           17.685]},
#               {'confidence': 0.961,
#                'duration': 0.12222,
#                'loudness_end': 0.0,
#                'loudness_max': -15.339,
#                'loudness_max_time': 0.03057,
#                'loudness_start': -29.821,
#                'pitches': [0.185,
#                            0.098,
#                            0.065,
#                            0.113,
#                            0.076,
#                            0.128,
#                            0.084,
#                            0.428,
#                            1.0,
#                            0.303,
#                            0.173,
#                            0.09],
#                'start': 0.80671,
#                'timbre': [41.039,
#                           81.049,
#                           25.458,
#                           21.508,
#                           122.523,
#                           0.804,
#                           12.277,
#                           -106.223,
#                           -24.243,
#                           8.965,
#                           0.069,
#                           -2.364]},
#               {'confidence': 0.339,
#                'duration': 0.10549,
#                'loudness_end': 0.0,
#                'loudness_max': -15.711,
#                'loudness_max_time': 0.02522,
#                'loudness_start': -21.676,
#                'pitches': [0.321,
#                            0.128,
#                            0.095,
#                            0.111,
#                            0.424,
#                            1.0,
#                            0.403,
#                            0.139,
#                            0.212,
#                            0.141,
#                            0.172,
#                            0.118],
#                'start': 0.92893,
#                'timbre': [41.348,
#                           24.527,
#                           74.614,
#                           50.105,
#                           108.446,
#                           -28.258,
#                           22.144,
#                           -37.684,
#                           -27.642,
#                           -38.183,
#                           2.331,
#                           -8.823]},
#               {'confidence': 0.738,
#                'duration': 0.14993,
#                'loudness_end': 0.0,
#                'loudness_max': -11.78,
#                'loudness_max_time': 0.04157,
#                'loudness_start': -21.924,
#                'pitches': [0.217,
#                            0.153,
#                            0.085,
#                            0.144,
#                            0.114,
#                            1.0,
#                            0.215,
#                            0.074,
#                            0.116,
#                            0.132,
#                            0.151,
#                            0.114],
#                'start': 1.03442,
#                'timbre': [42.134,
#                           75.927,
#                           38.397,
#                           70.647,
#                           122.582,
#                           6.556,
#                           30.737,
#                           -50.901,
#                           -30.645,
#                           -57.746,
#                           -6.47,
#                           5.74]},
#               {'confidence': 1.0,
#                'duration': 0.10998,
#                'loudness_end': 0.0,
#                'loudness_max': -5.434,
#                'loudness_max_time': 0.02089,
#                'loudness_start': -23.904,
#                'pitches': [0.757,
#                            0.421,
#                            0.452,
#                            0.895,
#                            1.0,
#                            0.839,
#                            0.475,
#                            0.613,
#                            0.319,
#                            0.453,
#                            0.817,
#                            0.721],
#                'start': 1.18435,
#                'timbre': [46.343,
#                           85.327,
#                           2.277,
#                           112.491,
#                           116.344,
#                           -47.36,
#                           -33.602,
#                           -37.761,
#                           -11.943,
#                           4.045,
#                           -1.959,
#                           17.034]},
#               {'confidence': 0.883,
#                'duration': 0.21492,
#                'loudness_end': 0.0,
#                'loudness_max': -5.052,
#                'loudness_max_time': 0.01078,
#                'loudness_start': -24.559,
#                'pitches': [0.391,
#                            0.197,
#                            0.129,
#                            0.148,
#                            0.143,
#                            0.754,
#                            1.0,
#                            0.541,
#                            0.226,
#                            0.318,
#                            0.311,
#                            0.25],
#                'start': 1.29433,
#                'timbre': [48.085,
#                           22.073,
#                           -1.963,
#                           67.42,
#                           76.075,
#                           -83.354,
#                           5.405,
#                           -21.847,
#                           -9.789,
#                           -2.949,
#                           -5.647,
#                           -14.0]},
#               {'confidence': 1.0,
#                'duration': 0.15728,
#                'loudness_end': 0.0,
#                'loudness_max': -2.598,
#                'loudness_max_time': 0.03701,
#                'loudness_start': -21.789,
#                'pitches': [0.294,
#                            0.313,
#                            0.444,
#                            0.471,
#                            0.431,
#                            1.0,
#                            0.761,
#                            0.322,
#                            0.215,
#                            0.411,
#                            0.481,
#                            0.29],
#                'start': 1.50925,
#                'timbre': [49.789,
#                           64.846,
#                           41.555,
#                           44.338,
#                           115.408,
#                           69.007,
#                           4.85,
#                           31.387,
#                           2.074,
#                           -47.906,
#                           16.858,
#                           -5.022]},
#               {'confidence': 0.396,
#                'duration': 0.23166,
#                'loudness_end': 0.0,
#                'loudness_max': -5.673,
#                'loudness_max_time': 0.00739,
#                'loudness_start': -20.01,
#                'pitches': [0.803,
#                            0.431,
#                            0.264,
#                            0.584,
#                            0.393,
#                            0.734,
#                            1.0,
#                            0.763,
#                            0.344,
#                            0.65,
#                            0.775,
#                            0.886],
#                'start': 1.66653,
#                'timbre': [44.315,
#                           61.248,
#                           -48.158,
#                           80.585,
#                           45.839,
#                           -108.143,
#                           -24.692,
#                           14.606,
#                           -9.561,
#                           -18.582,
#                           -16.185,
#                           3.526]},
#               {'confidence': 1.0,
#                'duration': 0.11034,
#                'loudness_end': 0.0,
#                'loudness_max': -6.56,
#                'loudness_max_time': 0.01972,
#                'loudness_start': -29.204,
#                'pitches': [0.735,
#                            0.554,
#                            0.643,
#                            0.871,
#                            0.665,
#                            1.0,
#                            0.699,
#                            0.739,
#                            0.485,
#                            0.619,
#                            0.665,
#                            0.611],
#                'start': 1.89819,
#                'timbre': [44.684,
#                           106.488,
#                           -3.38,
# ...
#            'duration': 160.12749,
#            'echoprint_version': 4.12,
